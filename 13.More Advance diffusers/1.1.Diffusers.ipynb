# %% [markdown]
# ```
# Generative AI with Python, by Fernando Amaral
# ```

# %% [markdown]
# # Setup

# %%
#gpu
# !pip install diffusers transformers accelerate safetensors

# %%
from diffusers import DiffusionPipeline
import torch
import matplotlib.pyplot as plt

# %%
pipeline = DiffusionPipeline.from_pretrained(
        pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0",
        torch_dtype=torch.float16,
        use_safetensors=True
    ).to("cuda")
pipeline.enable_attention_slicing()
generator = torch.Generator(device="cuda").manual_seed(123)
image = pipeline(prompt="A photo realistic clown fish in an aquarium",generator=generator,num_inference_steps=20).images[0]

# %%
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
pipeline.components

# %%
pipeline.scheduler

# %%
pipeline.scheduler.compatibles

# %%
from diffusers import PNDMScheduler

# %%
pipeline.scheduler = PNDMScheduler.from_config(pipeline.scheduler.config)

image = pipeline(prompt="A photo realistic clown fish in an aquarium",generator=generator,num_inference_steps=20).images[0]
plt.axis('off')
plt.imshow(image)
plt.show()
